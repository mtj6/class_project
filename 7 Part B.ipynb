# %%
import pandas as pd
df = pd.read_csv('uforeports.csv')
df.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %% [markdown]
# How many ufos sightings have been reported in Alaska?

# %%
g = df.groupby('State')

# %%
g.get_group('AK')
# Out:
#                                                     City Colors Reported  \
# 8                                                Eklutna             NaN
# 19                                            Bering Sea             RED
# 103                                            Anchorage             NaN
# 106                                            Fairbanks             NaN
# 262                                            Fairbanks             NaN
# 413                                               Arctic             NaN
# 456                                             Nelchina             NaN
# 459                                   Northeast Cape AFS             NaN
# 467                                   St Lawrence Island             NaN
# 751                                               Nenana             NaN
# 1306                                      Delta Junction          ORANGE
# 1339                                Kodiak Naval Station             NaN
# ...

# %% [markdown]
# Answer = 116 sightings

# %% [markdown]
# On what day of the week are ufo sightings most commonly reported?

# %%
df.dtypes
# Out:
# City               object
# Colors Reported    object
# Shape Reported     object
# State              object
# Time               object
# dtype: object

# %%
df['Time'] = pd.to_datetime(df.Time)
df.dtypes
# Out:
# City                       object
# Colors Reported            object
# Shape Reported             object
# State                      object
# Time               datetime64[ns]
# dtype: object

# %%
df['Day'] = df.Time.dt.weekday_name

# %%
df
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# 5               Valley City             NaN           DISK    ND
# 6               Crater Lake             NaN         CIRCLE    CA
# 7                      Alma             NaN           DISK    MI
# 8                   Eklutna             NaN          CIGAR    AK
# 9                   Hubbard             NaN       CYLINDER    OR
# 10                  Fontana             NaN          LIGHT    CA
# 11                 Waterloo             NaN       FIREBALL    AL
# 12                   Belton             RED         SPHERE    SC
# ...

# %%
g = df.groupby('Day')
g.count()
# Out:
#            City  Colors Reported  Shape Reported  State  Time
# Day
# Friday     2665              461            2295   2669  2669
# Monday     2297              335            1953   2300  2300
# Saturday   2683              429            2292   2687  2687
# Sunday     2684              402            2223   2689  2689
# Thursday   2596              403            2264   2598  2598
# Tuesday    2820              485            2448   2822  2822
# Wednesday  2471              367            2122   2476  2476

# %%
numday = g.count()
numday.max()
# Out:
# City               2820
# Colors Reported     485
# Shape Reported     2448
# State              2822
# Time               2822
# dtype: int64

# %% [markdown]
# Answer = Tuesdays
